# %% [markdown]
# ### GOLD LAYER TRANSFORMATION & AGGREGATION : SHOPPINGMART DATA

# %%
from pyspark.sql.functions import *

order_df = spark.read.parquet("Files/ShoppingMart_Silver_Orders/ShoppingMart_Customer_ordersdata")
review_df = spark.read.parquet("Files/ShoppingMart_Silver_Reviews/ShoppingMart_reviews")
social_df = spark.read.parquet("Files/ShoppingMart_Silver_Social_Media/ShoppingMart_Social_Media")
weblogs_df = spark.read.parquet("Files/ShoppingMart_Silver_Web_Logs/ShoppingMart_Web_Logs")

display(weblogs_df)
# Out:
# StatementMeta(, 5964b8c6-9faf-40bc-8372-50fb30c7a587, 24, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 98d08697-bf91-4f15-962e-b8bfb9458e66)

# %%
#KPI-1 : Aggregate web log data to measure enagagement per user on each page and action
# weblogs_df = spark.read.parquet("Files/ShoppingMart_Silver_Web_Logs/ShoppingMart_Web_Logs")
weblogs_df = weblogs_df.groupBy("user_id","page","action").count()
weblogs_df.write.mode("overwrite").parquet("Files/ShoppingMart_Gold_Web_Logs/ShoppingMart_Web_Logs")
# display(weblogs_df)
# Out:
# StatementMeta(, 5964b8c6-9faf-40bc-8372-50fb30c7a587, 25, Finished, Available, Finished, False)

# %%
#KPI-2 : Aggregate unstructured social media data to track sentiments trends across different platforms
# social_df = spark.read.parquet("Files/ShoppingMart_Silver_Social_Media/ShoppingMart_Social_Media")
social_df = social_df.groupBy("platform","sentiment").count()
social_df.write.mode("overwrite").parquet("Files/ShoppingMart_Gold_Social_Media/ShoppingMart_Social_Media")
# display(social_df)
# Out:
# StatementMeta(, 5964b8c6-9faf-40bc-8372-50fb30c7a587, 26, Finished, Available, Finished, False)

# %%
#KPI-3 : Aggregation product reviews to calculate the average rating per product
# review_df = spark.read.parquet("Files/ShoppingMart_Silver_Reviews/ShoppingMart_reviews")
review_df = review_df.groupBy("product_id").agg(avg("rating").alias("Average_Rating"))
review_df.write.mode("overwrite").parquet("Files/ShoppingMart_Gold_Reviews/ShoppingMart_reviews")
# display(review_df)
# Out:
# StatementMeta(, 5964b8c6-9faf-40bc-8372-50fb30c7a587, 27, Finished, Available, Finished, False)

# %%
order_df.write.mode("overwrite").parquet("Files/ShoppingMart_Gold_Orders/ShoppingMart_Customer_ordersdata")
# Out:
# StatementMeta(, 5964b8c6-9faf-40bc-8372-50fb30c7a587, 28, Finished, Available, Finished, False)
